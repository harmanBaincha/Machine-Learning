# %%
import pandas as pd
import numpy as np

# %%
dataframe=pd.read_csv("C:/Users/Dell Inspiron/Downloads/ml tutorial/prisoners.csv")
dataframe.head(5)
# Out:
#             STATE/UT  YEAR  No. of Inmates benefitted by Elementary Education  \
# 0     Andhra Pradesh  2013                                               9480
# 1  Arunachal Pradesh  2013                                                  0
# 2              Assam  2013                                                676
# 3              Bihar  2013                                               1693
# 4        Chhatisgarh  2013                                               1664
#
#    No. of Inmates benefitted by Adult Education  \
# 0                                         13758
# 1                                             0
# 2                                           750
# 3                                          3013
# 4                                          1803
#
#    No. of Inmates benefitted by Higher Education  \
# 0                                            672
# 1                                              0
# 2                                             14
# ...

# %%
dataframe.tail(5)
# Out:
#         STATE/UT  YEAR  No. of Inmates benefitted by Elementary Education  \
# 30  D & N Haveli  2013                                                  0
# 31   Daman & Diu  2013                                                  0
# 32         Delhi  2013                                               1458
# 33   Lakshadweep  2013                                                  0
# 34   Pondicherry  2013                                                  0
#
#     No. of Inmates benefitted by Adult Education  \
# 30                                             0
# 31                                             0
# 32                                          1187
# 33                                             0
# 34                                             0
#
#     No. of Inmates benefitted by Higher Education  \
# 30                                              0
# 31                                              0
# 32                                            908
# ...

# %%
dataframe.describe()
# Out:
#          YEAR  No. of Inmates benefitted by Elementary Education  \
# count    35.0                                          35.000000
# mean   2013.0                                        1057.914286
# std       0.0                                        2078.196777
# min    2013.0                                           0.000000
# 25%    2013.0                                           0.000000
# 50%    2013.0                                         167.000000
# 75%    2013.0                                        1294.500000
# max    2013.0                                        9480.000000
#
#        No. of Inmates benefitted by Adult Education  \
# count                                     35.000000
# mean                                    1534.857143
# std                                     3022.110503
# min                                        0.000000
# 25%                                        6.500000
# 50%                                      237.000000
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 6 columns):
# STATE/UT                                             35 non-null object
# YEAR                                                 35 non-null int64
# No. of Inmates benefitted by Elementary Education    35 non-null int64
# No. of Inmates benefitted by Adult Education         35 non-null int64
# No. of Inmates benefitted by Higher Education        35 non-null int64
# No. of Inmates benefitted by Computer Course         35 non-null int64
# dtypes: int64(5), object(1)
# memory usage: 1.8+ KB

# %%
df=dataframe.loc[dataframe['No. of Inmates benefitted by Elementary Education']==0]

# %%
df['No. of Inmates benefitted by Elementary Education'].count()
# Total no of rows having zero value for this column is 9 or we can say that total no of states that are not benefitted by this program are 9
# Out:
# 10

# %%
df=dataframe.loc[dataframe['No. of Inmates benefitted by Adult Education']==0]

df['No. of Inmates benefitted by Adult Education'].count()
# Total no of rows having zero value for this column is 9 or we can say that total no of states that are not benefitted by this program are 9
# Out:
# 9

# %%
df=dataframe.loc[dataframe['No. of Inmates benefitted by Computer Course']==0]
df['No. of Inmates benefitted by Computer Course'].count()
# Total no of rows having zero value for this column is 13 or we can say that total no of states that are not benefitted by this program are 13
# Out:
# 13

# %%
dataframe.columns=['a', 'b', 'c', 'd', 'e', 'f']
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 6 columns):
# a    35 non-null object
# b    35 non-null int64
# c    35 non-null int64
# d    35 non-null int64
# e    35 non-null int64
# f    35 non-null int64
# dtypes: int64(5), object(1)
# memory usage: 1.8+ KB

# %%
dataframe.describe()
# Out:
#             b            c             d            e            f
# count    35.0    35.000000     35.000000    35.000000    35.000000
# mean   2013.0  1057.914286   1534.857143   237.457143   210.171429
# std       0.0  2078.196777   3022.110503   375.614191   359.117340
# min    2013.0     0.000000      0.000000     0.000000     0.000000
# 25%    2013.0     0.000000      6.500000     2.000000     0.000000
# 50%    2013.0   167.000000    237.000000    33.000000    38.000000
# 75%    2013.0  1294.500000   1733.500000   234.500000   227.500000
# max    2013.0  9480.000000  13758.000000  1353.000000  1417.000000

# %%
dataframe.head()
# Out:
#                    a     b     c      d    e     f
# 0     Andhra Pradesh  2013  9480  13758  672   170
# 1  Arunachal Pradesh  2013     0      0    0     0
# 2              Assam  2013   676    750   14    30
# 3              Bihar  2013  1693   3013  125  1417
# 4        Chhatisgarh  2013  1664   1803  192   103

# %%
dataframe.query('c+d+e+f==0')
# these are the states that are not benefitted by any educational program. 
#These are mainly eastern sates or union territories
# Out:
#                     a     b  c  d  e  f
# 1   Arunachal Pradesh  2013  0  0  0  0
# 15            Manipur  2013  0  0  0  0
# 18           Nagaland  2013  0  0  0  0
# 22             Sikkim  2013  0  0  0  0
# 30       D & N Haveli  2013  0  0  0  0
# 31        Daman & Diu  2013  0  0  0  0
# 33        Lakshadweep  2013  0  0  0  0
# 34        Pondicherry  2013  0  0  0  0

# %%
dataframe['total_benefitted']=dataframe.iloc[:,[2,3,4,5]].sum(axis=1, skipna=True)
dataframe['total_benefitted']
dataframe
# Out:
#                     a     b     c      d     e     f  total_benefitted
# 0      Andhra Pradesh  2013  9480  13758   672   170             24080
# 1   Arunachal Pradesh  2013     0      0     0     0                 0
# 2               Assam  2013   676    750    14    30              1470
# 3               Bihar  2013  1693   3013   125  1417              6248
# 4         Chhatisgarh  2013  1664   1803   192   103              3762
# 5                 Goa  2013     7      0     6    88               101
# 6             Gujarat  2013  2310   3133   875   966              7284
# 7             Haryana  2013  1131    774  1112   243              3260
# 8    Himachal Pradesh  2013    33     80    26     0               139
# 9     Jammu & Kashmir  2013   102    124    33    34               293
# 10          Jharkhand  2013  3008   2595   138   574              6315
# 11          Karnataka  2013   633    568   170    12              1383
# ...

# %%
df1=dataframe
df1
# Out:
#                     a     b     c      d     e     f  total_benefitted
# 0      Andhra Pradesh  2013  9480  13758   672   170             24080
# 1   Arunachal Pradesh  2013     0      0     0     0                 0
# 2               Assam  2013   676    750    14    30              1470
# 3               Bihar  2013  1693   3013   125  1417              6248
# 4         Chhatisgarh  2013  1664   1803   192   103              3762
# 5                 Goa  2013     7      0     6    88               101
# 6             Gujarat  2013  2310   3133   875   966              7284
# 7             Haryana  2013  1131    774  1112   243              3260
# 8    Himachal Pradesh  2013    33     80    26     0               139
# 9     Jammu & Kashmir  2013   102    124    33    34               293
# 10          Jharkhand  2013  3008   2595   138   574              6315
# 11          Karnataka  2013   633    568   170    12              1383
# ...

# %%
total=df1.iloc[:,[2,3,4,5]].sum().tolist()
total
# Out:
# [37027, 53720, 8311, 7356]

# %%
total.insert(0,np.nan)
total.insert(1,np.nan)
total.insert(6,np.nan)

# %%
total
# Out:
# [nan, nan, 37027, 53720, 8311, 7356, nan]

# %%
df1.append(pd.DataFrame.from_dict([dict( zip(df1.keys().tolist(),total))]), ignore_index = True)
# Out:
#                     a       b      c      d     e     f  total_benefitted
# 0      Andhra Pradesh  2013.0   9480  13758   672   170           24080.0
# 1   Arunachal Pradesh  2013.0      0      0     0     0               0.0
# 2               Assam  2013.0    676    750    14    30            1470.0
# 3               Bihar  2013.0   1693   3013   125  1417            6248.0
# 4         Chhatisgarh  2013.0   1664   1803   192   103            3762.0
# 5                 Goa  2013.0      7      0     6    88             101.0
# 6             Gujarat  2013.0   2310   3133   875   966            7284.0
# 7             Haryana  2013.0   1131    774  1112   243            3260.0
# 8    Himachal Pradesh  2013.0     33     80    26     0             139.0
# 9     Jammu & Kashmir  2013.0    102    124    33    34             293.0
# 10          Jharkhand  2013.0   3008   2595   138   574            6315.0
# 11          Karnataka  2013.0    633    568   170    12            1383.0
# ...

# %%
# Plotting
import matplotlib.pyplot as plt

# %%
States = df1['a'].values.tolist()
States
# Out:
# ['Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chhatisgarh',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu & Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Orissa',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamilnadu',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttaranchal',
#  'West Bengal',
#  'A & N Islands',
#  'Chandigarh',
#  'D & N Haveli',
#  'Daman & Diu',
#  'Delhi',
#  'Lakshadweep',
#  'Pondicherry']

# %%
TotalBenefitted = df1['total_benefitted'].values.tolist()
TotalBenefitted
# Out:
# [24080,
#  0,
#  1470,
#  6248,
#  3762,
#  101,
#  7284,
#  3260,
#  139,
#  293,
#  6315,
#  1383,
#  526,
#  12004,
#  5301,
#  0,
#  31,
#  43,
#  0,
#  1896,
#  1211,
#  1389,
#  0,
#  2967,
#  34,
#  17534,
#  348,
#  4495,
#  223,
#  350,
#  0,
#  0,
#  3727,
#  0,
#  0]

# %%
plt.bar(States,TotalBenefitted , align='center', alpha=0.5)
plt.show()

# %%
df1.columns=['State/UT', 'Year', 'No. of Inmates benefitted by Elementary Education', 'No. of Inmates benefitted by Adult Education', 'No. of Inmates benefitted by Higher Education', 'No. of Inmates benefitted by Computer Course','total_benefitted']

# %%
df1
# Out:
#              State/UT  Year  \
# 0      Andhra Pradesh  2013
# 1   Arunachal Pradesh  2013
# 2               Assam  2013
# 3               Bihar  2013
# 4         Chhatisgarh  2013
# 5                 Goa  2013
# 6             Gujarat  2013
# 7             Haryana  2013
# 8    Himachal Pradesh  2013
# 9     Jammu & Kashmir  2013
# 10          Jharkhand  2013
# 11          Karnataka  2013
# 12             Kerala  2013
# 13     Madhya Pradesh  2013
# 14        Maharashtra  2013
# 15            Manipur  2013
# 16          Meghalaya  2013
# 17            Mizoram  2013
# 18           Nagaland  2013
# 19             Orissa  2013
# 20             Punjab  2013
# 21          Rajasthan  2013
# 22             Sikkim  2013
# 23          Tamilnadu  2013
# 24            Tripura  2013
# 25      Uttar Pradesh  2013
# 26        Uttaranchal  2013
# 27        West Bengal  2013
# 28      A & N Islands  2013
# 29         Chandigarh  2013
# 30       D & N Haveli  2013
# 31        Daman & Diu  2013
# ...

# %%
df1.keys().tolist()[2:-1]
# Out:
# ['No. of Inmates benefitted by Elementary Education',
#  'No. of Inmates benefitted by Adult Education',
#  'No. of Inmates benefitted by Higher Education',
#  'No. of Inmates benefitted by Computer Course']

# %%
plt.pie(total[2:-1], labels=df1.keys().tolist()[2:-1],
autopct='%1.1f%%', shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x7cc306f48>,
# ...
#  [Text(-1.0152992676038635, -0.4232816995844003, 'No. of Inmates benefitted by Elementary Education'),
#   Text(1.0974924937466948, -0.07423089767516729, 'No. of Inmates benefitted by Adult Education'),
#   Text(-0.21095365752223977, 1.0795825833987829, 'No. of Inmates benefitted by Higher Education'),
#   Text(-0.6705097975572272, 0.8720186989851574, 'No. of Inmates benefitted by Computer Course')],
#  [Text(-0.5537996005111983, -0.23088092704603652, '34.8%'),
#   Text(0.5986322693163789, -0.04048958055009125, '50.5%'),
#   Text(-0.11506563137576713, 0.5888632273084269, '7.8%'),
#   Text(-0.36573261684939656, 0.47564656308281306, '6.9%')])
