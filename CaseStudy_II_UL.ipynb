# %%
import matplotlib.pyplot as plt

# %%
from mpl_toolkits.mplot3d import Axes3D
import cv2

# %%
from numpy import asarray
img = plt.imread('F:/ml tutorial/dogs.jpeg')/255
data=asarray(img)

# %%
data.size
data.shape
# Out:
# (185, 272, 3)

# %%
data = data.reshape((data.shape[0] * data.shape[1], 3))

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3, random_state=0).fit(data)
pic2show = kmeans.cluster_centers_[kmeans.labels_]
cluster_pic = pic2show.reshape(img.shape[0], img.shape[1], img.shape[2])
plt.imshow(cluster_pic)

# %%
Colors = kmeans.cluster_centers_

# %%
Colors
# Out:
# array([[0.11574524, 0.08464181, 0.08029802],
#        [0.9862227 , 0.97130722, 0.95355911],
#        [0.82602379, 0.68562906, 0.56360945]])

# %%
labels=kmeans.labels_

# %%
labels
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
l=labels

# %%
l.reshape(50320,1)
# Out:
# array([[1],
#        [1],
#        [1],
#        ...,
#        [1],
#        [1],
#        [1]])

# %%
figure_size = 15
plt.figure(figsize=(figure_size,figure_size))
plt.subplot(1,2,1),plt.imshow(img)
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(1,2,2),plt.imshow(cluster_pic)
plt.title('Segmented Image '), plt.xticks([]), plt.yticks([])
plt.show()
